# %% [markdown]
# # Pandas Dataframe
# ![image.png](attachment:7639a7e5-edcc-4317-8e2a-b4f4fca3817c.png)

# %% [markdown]
# ### Creating dataframe with dictionary

# %%
students = {
    "Name" : ["Joe", "Nat", "Harry", "Sam", "Monica"],
    "Age" : [20, 21, 19, 20, 22],
    "Marks" : [85.10, 77.80, 91.54, 88.78, 60.55],
    "Grade" : ["A", "B", "A", "A", "B"],
    "Hobby" : ["Swimming", "Reading", "Music", "Painting", "Dancing"]
}

# %%
type(students)
# Out:
# dict

# %%
students
# Out:
# {'Name': ['Joe', 'Nat', 'Harry', 'Sam', 'Monica'],
#  'Age': [20, 21, 19, 20, 22],
#  'Marks': [85.1, 77.8, 91.54, 88.78, 60.55],
#  'Grade': ['A', 'B', 'A', 'A', 'B'],
#  'Hobby': ['Swimming', 'Reading', 'Music', 'Painting', 'Dancing']}

# %%
import pandas as pd

# %%
A = pd.DataFrame(students, index=["S1", "S2", "S3", "S4", "S5"])

# %%
A
# Out:
#       Name  Age  Marks Grade     Hobby
# S1     Joe   20  85.10     A  Swimming
# S2     Nat   21  77.80     B   Reading
# S3   Harry   19  91.54     A     Music
# S4     Sam   20  88.78     A  Painting
# S5  Monica   22  60.55     B   Dancing

# %%
type(A)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Check number of rows and number of columns

# %% [markdown]
# ![image.png](attachment:cab471eb-998d-442f-9c04-83fb98aac821.png)

# %%
A.shape
# Out:
# (5, 5)

# %% [markdown]
# ### A.shape results stored in (n_rows, n_columns)

# %%
nrows, ncols = A.shape

# %%
nrows
# Out:
# 5

# %%
ncols
# Out:
# 5

# %% [markdown]
# ### Check the column names

# %%
A.columns
# Out:
# Index(['Name', 'Age', 'Marks', 'Grade', 'Hobby'], dtype='object')

# %% [markdown]
# ### Check the row names

# %%
A.index
# Out:
# Index(['S1', 'S2', 'S3', 'S4', 'S5'], dtype='object')

# %% [markdown]
# ### Check the datatypes of column

# %%
A.dtypes
# Out:
# Name      object
# Age        int64
# Marks    float64
# Grade     object
# Hobby     object
# dtype: object

# %% [markdown]
# ### Columns which contain text are consided as object in the DataFrame

# %% [markdown]
# ### All above information can be seen using info method

# %%
A.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, S1 to S5
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    5 non-null      object
#  1   Age     5 non-null      int64
#  2   Marks   5 non-null      float64
#  3   Grade   5 non-null      object
#  4   Hobby   5 non-null      object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 240.0+ bytes

# %% [markdown]
# ### 2. Creating Dataframe with list (Row wise list)

# %%
e1 = [101, "Utkarsh", "Gaikwad", "Data Science", 15000]
e2 = [102, "Sarthak", "More", "HR", 35000]
e3 = [103, "Aditi", "More", "Sales", None]

# %%
from pandas import DataFrame

# %%
emp = DataFrame(
    [e1, e2, e3], 
    columns=["Emp_ID", "First", "Last", "Dept", "Sal"],
    index = ["E1", "E2", "E3"]
)

# %%
emp
# Out:
#     Emp_ID    First     Last          Dept      Sal
# E1     101  Utkarsh  Gaikwad  Data Science  15000.0
# E2     102  Sarthak     More            HR  35000.0
# E3     103    Aditi     More         Sales      NaN

# %% [markdown]
# ### Inside Dataframe NaN - Not a Number (Value is Missing or blank)

# %% [markdown]
# ### shape, columns, index, dtypes - Attributes of Dataframe (No need of round brackets)

# %%
emp.shape
# Out:
# (3, 5)

# %%
emp.columns
# Out:
# Index(['Emp_ID', 'First', 'Last', 'Dept', 'Sal'], dtype='object')

# %%
emp.index
# Out:
# Index(['E1', 'E2', 'E3'], dtype='object')

# %%
emp.dtypes
# Out:
# Emp_ID      int64
# First      object
# Last       object
# Dept       object
# Sal       float64
# dtype: object

# %%
# info is function/method of a dataframe
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, E1 to E3
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Emp_ID  3 non-null      int64
#  1   First   3 non-null      object
#  2   Last    3 non-null      object
#  3   Dept    3 non-null      object
#  4   Sal     2 non-null      float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 144.0+ bytes

# %% [markdown]
# ### Series - used to store single values (It will having only column)

# %%
sbi = [800, 810, 815.5, 812, 750, 781]
type(sbi)
# Out:
# list

# %%
stock = pd.Series(
    sbi,
    index = ["Jan", "Feb", "Mar", "Apr", "May", "Jun"],
    name="SBI Stock Price"
)

# %%
stock
# Out:
# Jan    800.0
# Feb    810.0
# Mar    815.5
# Apr    812.0
# May    750.0
# Jun    781.0
# Name: SBI Stock Price, dtype: float64

# %%
type(stock)
# Out:
# pandas.core.series.Series

# %%
stock.dtypes
# Out:
# dtype('float64')

# %%
stock.index
# Out:
# Index(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun'], dtype='object')

# %%
stock.name
# Out:
# 'SBI Stock Price'

# %%
stock.shape
# Out:
# (6,)

# %%
stock.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 6 entries, Jan to Jun
# Series name: SBI Stock Price
# Non-Null Count  Dtype
# --------------  -----
# 6 non-null      float64
# dtypes: float64(1)
# memory usage: 268.0+ bytes

# %% [markdown]
# ### Once completed type done in chat

# %% [markdown]
# ### Reading file from local system
# For file press shift + Right Click > Copy as path (just add r before string)
# ![image.png](attachment:4a7f51b5-0626-4097-a6f5-c5e88d2329ec.png)

# %%
file_path = r"C:\ETLHive lectures by me\ETLHive Lectures by me - Ravet\Session 6 - DataFrames\50_Startups.csv"
df = pd.read_csv(file_path)
df
# Out:
#           RND      ADMIN        MKT       STATE     PROFIT
# 0   165349.20  136897.80  471784.10    New York  192261.83
# 1   162597.70  151377.59  443898.53  California  191792.06
# 2   153441.51  101145.55  407934.54     Florida  191050.39
# 3   144372.41  118671.85  383199.62    New York  182901.99
# 4   142107.34   91391.77  366168.42     Florida  166187.94
# 5   131876.90   99814.71  362861.36    New York  156991.12
# 6   134615.46  147198.87  127716.82  California  156122.51
# 7   130298.13  145530.06  323876.68     Florida  155752.60
# 8   120542.52  148718.95  311613.29    New York  152211.77
# 9   123334.88  108679.17  304981.62  California  149759.96
# 10  101913.08  110594.11  229160.95     Florida  146121.95
# 11  100671.96   91790.61  249744.55  California  144259.40
# 12   93863.75  127320.38  249839.44     Florida  141585.52
# 13   91992.39  135495.07  252664.93  California  134307.35
# Name: PROFIT, dtype: float64

# %%
# DataFrame
df[["PROFIT"]]
# Out:
#        PROFIT
# 0   192261.83
# 1   191792.06
# 2   191050.39
# 3   182901.99
# 4   166187.94
# 5   156991.12
# 6   156122.51
# 7   155752.60
# 8   152211.77
# 9   149759.96
# 10  146121.95
# 11  144259.40
# 12  141585.52
# 13  134307.35
# 14  132602.65
# 15  129917.04
# 16  126992.93
# 17  125370.37
# 18  124266.90
# 19  122776.86
# 20  118474.03
# 21  111313.02
# 22  110352.25
# 23  108733.99
# 24  108552.04
# 25  107404.34
# 26  105733.54
# 27  105008.31
# 28  103282.38
# 29  101004.64
# 30   99937.59
# 31   97483.56
# 32   97427.84
# 33   96778.92
# 34   96712.80
# 35   96479.51
# 36   90708.19
# 37   89949.14
# 38   81229.06
# 39   81005.76
# 40   78239.91
# 41   77798.83
# 42   71498.49
# 43   69758.98
# 44   65200.33
# 45   64926.08
# 46   49490.75
# 47   42559.73
# 48   35673.41
# 49   14681.40

# %%
df[["STATE", "ADMIN", "PROFIT"]]
# Out:
#          STATE      ADMIN     PROFIT
# 0     New York  136897.80  192261.83
# 1   California  151377.59  191792.06
# 2      Florida  101145.55  191050.39
# 3     New York  118671.85  182901.99
# 4      Florida   91391.77  166187.94
# 5     New York   99814.71  156991.12
# 6   California  147198.87  156122.51
# 7      Florida  145530.06  155752.60
# 8     New York  148718.95  152211.77
# 9   California  108679.17  149759.96
# 10     Florida  110594.11  146121.95
# 11  California   91790.61  144259.40
# 12     Florida  127320.38  141585.52
# 13  California  135495.07  134307.35
# 14     Florida  156547.42  132602.65
# 15    New York  122616.84  129917.04
# 16  California  121597.55  126992.93
# 17    New York  145077.58  125370.37
# 18     Florida  114175.79  124266.90
# 19    New York  153514.11  122776.86
# 20  California  113867.30  118474.03
# 21    New York  153773.43  111313.02
# 22     Florida  122782.75  110352.25
# 23     Florida  105751.03  108733.99
# 24    New York   99281.34  108552.04
# 25  California  139553.16  107404.34
# 26     Florida  144135.98  105733.54
# 27    New York  127864.55  105008.31
# 28     Florida  182645.56  103282.38
# 29    New York  153032.06  101004.64
# 30     Florida  115641.28   99937.59
# 31    New York  152701.92   97483.56
# 32  California  129219.61   97427.84
# 33     Florida  103057.49   96778.92
# 34  California  157693.92   96712.80
# 35    New York   85047.44   96479.51
# 36     Florida  127056.21   90708.19
# 37  California   51283.14   89949.14
# 38    New York   65947.93   81229.06
# 39  California   82982.09   81005.76
# 40  California  118546.05   78239.91
# 41     Florida   84710.77   77798.83
# 42  California   96189.63   71498.49
# 43    New York  127382.30   69758.98
# 44  California  154806.14   65200.33
# 45    New York  124153.04   64926.08
# 46     Florida  115816.21   49490.75
# 47  California  135426.92   42559.73
# 48    New York   51743.15   35673.41
# 49  California  116983.80   14681.40

# %% [markdown]
# ### Row subsetting
# 1. iloc(row_index, column_index)
# 2. loc(row_name, column_name)

# %%
df.iloc[5, :]
# Out:
# RND        131876.9
# ADMIN      99814.71
# MKT       362861.36
# STATE      New York
# PROFIT    156991.12
# Name: 5, dtype: object

# %%
df.iloc[5, :].to_frame()
# Out:
#                 5
# RND      131876.9
# ADMIN    99814.71
# MKT     362861.36
# STATE    New York
# PROFIT  156991.12

# %%
df.iloc[5, :].to_frame().T
# Out:
#         RND     ADMIN        MKT     STATE     PROFIT
# 5  131876.9  99814.71  362861.36  New York  156991.12

# %% [markdown]
# ### Get from row 8 to 14

# %%
df.iloc[8:15, :]
# Out:
#           RND      ADMIN        MKT       STATE     PROFIT
# 8   120542.52  148718.95  311613.29    New York  152211.77
# 9   123334.88  108679.17  304981.62  California  149759.96
# 10  101913.08  110594.11  229160.95     Florida  146121.95
# 11  100671.96   91790.61  249744.55  California  144259.40
# 12   93863.75  127320.38  249839.44     Florida  141585.52
# 13   91992.39  135495.07  252664.93  California  134307.35
# 14  119943.24  156547.42  256512.92     Florida  132602.65

# %%
df.loc[8:14 , :]
# Out:
#           RND      ADMIN        MKT       STATE     PROFIT
# 8   120542.52  148718.95  311613.29    New York  152211.77
# 9   123334.88  108679.17  304981.62  California  149759.96
# 10  101913.08  110594.11  229160.95     Florida  146121.95
# 11  100671.96   91790.61  249744.55  California  144259.40
# 12   93863.75  127320.38  249839.44     Florida  141585.52
# 13   91992.39  135495.07  252664.93  California  134307.35
# 14  119943.24  156547.42  256512.92     Florida  132602.65

# %%
df.iloc[[3, 7, 9], :]
# Out:
#          RND      ADMIN        MKT       STATE     PROFIT
# 3  144372.41  118671.85  383199.62    New York  182901.99
# 7  130298.13  145530.06  323876.68     Florida  155752.60
# 9  123334.88  108679.17  304981.62  California  149759.96

# %% [markdown]
# ### iloc - stands for index location (Requires slicing like a list where we add 1 in stop element)
# ### loc - stands for location (Requires exact start and stop)

# %% [markdown]
# ![image.png](attachment:83c1f106-8650-4768-bf14-23559c41f316.png)

# %%
df.iloc[2:6, 1:4]
# Out:
#        ADMIN        MKT     STATE
# 2  101145.55  407934.54   Florida
# 3  118671.85  383199.62  New York
# 4   91391.77  366168.42   Florida
# 5   99814.71  362861.36  New York

# %%
df.loc[2:5, "ADMIN":"STATE"]
# Out:
#        ADMIN        MKT     STATE
# 2  101145.55  407934.54   Florida
# 3  118671.85  383199.62  New York
# 4   91391.77  366168.42   Florida
# 5   99814.71  362861.36  New York

# %% [markdown]
# ### Get values of RND, MKT and STATE for row numbers 3, 9, 11, 20

# %%
df.iloc[[3, 9, 11, 20], [0, 2, 3]]
# Out:
#           RND        MKT       STATE
# 3   144372.41  383199.62    New York
# 9   123334.88  304981.62  California
# 11  100671.96  249744.55  California
# 20   76253.86  298664.47  California

# %%
df.loc[[3, 9, 11, 20], ["RND", "MKT", "STATE"]]
# Out:
#           RND        MKT       STATE
# 3   144372.41  383199.62    New York
# 9   123334.88  304981.62  California
# 11  100671.96  249744.55  California
# 20   76253.86  298664.47  California
